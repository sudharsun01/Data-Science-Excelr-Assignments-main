# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.15.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup as bs
import re

import warnings
warnings.filterwarnings('ignore')

# %%
iphone_reviews=[]

# %%
for i in range(1,51):

  op = []
  url = 'https://www.amazon.in/product-reviews/B0CHX68YG9/ref=acr_dp_hist_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews#reviews-filter-bar'+str(i)
  response = requests.get(url)
  soup = bs(response.content,"html.parser")
  reviews = soup.findAll('span',attrs= {"class","a-size-base review-text review-text-content"})
  for i in range(len(reviews)):
    op.append(reviews[i].text)
  iphone_reviews = iphone_reviews+op

# %%
iphone_reviews
# Out:
# ['\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n',
#  '\nIt’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of Apple is fabulous. Camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n',
#  '\nPerformance very strong Charging\n',
#  '\nLightning fast,titanium tantrums\n',
#  '\nFast charging\n',
#  '\nThis is my 1 st pro iPhone. And so far I’m really impressed with the performance and simplicity of the product.\n',
#  '\nbest iphone ever used\n',
#  '\nBattery 10/10Cemra 10/10Performance 10/10Disign 10/10Display 10/10Agar pese hai to isse Badiya phone nahi hai market ne Phil haal\n',
#  "\nI have purchased natural titanium and it's really awesome. My first phone purchased with my hardwork.\n",
#  '\nNo heating issue till now running well with the new software update I have installed lots of apps and the ph is running well\n',
#  '\nWe have received the iPhone 15 Pro Max, natural titanium color, and 256 GB storage capacity. The phone is good-looking and fast. It gets charged with the Apple 20W USB-C Power Adapter  (purchased separately). It also charges well using my 3-year-old Mi wireless charger (Qi charging). Overall, we are happy with the iPhone.\n']

# %%
reviews = ' '.join(iphone_reviews)

# %%
reviews = reviews.lower()
reviews
# Out:
# "\nit’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of apple is fabulous. camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n \nperformance very strong charging\n \nlightning fast,titanium tantrums\n \nfast charging\n \nthis is my 1 st pro iphone. and so far i’m really impressed with the performance and simplicity of the product.\n \nbest iphone ever used\n \nbattery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese hai to isse badiya phone nahi hai market ne phil haal\n \ni have purchased natural titanium and it's really awesome. my first phone purchased with my hardwork.\n \nno heating issue till now running well with the new software update i have installed lots of apps and the ph is running well\n \nwe have received the iphone 15 pro max, natural titanium color, and 256 gb storage capacity. the phone is good-looking and fast. it gets charged with the apple 20w usb-c power adapter  (purchased separately). it also charges well using my 3-year-old mi wireless charger (qi charging). overall, we are happy with the iphone.\n \nit’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of apple is fabulous. camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n \nperformance very strong charging\n \nlightning fast,titanium tantrums\n \nfast charging\n \nthis is my 1 st pro iphone. and so far i’m really impressed with the performance and simplicity of the product.\n \nbest iphone ever used\n \nbattery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese hai to isse badiya phone nahi hai market ne phil haal\n \ni have purchased natural titanium and it's really awesome. my first phone purchased with my hardwork.\n \nno heating issue till now running well with the new software update i have installed lots of apps and the ph is running well\n \nwe have received the iphone 15 pro max, natural titanium color, and 256 gb storage capacity. the phone is good-looking and fast. it gets charged with the apple 20w usb-c power adapter  (purchased separately). it also charges well using my 3-year-old mi wireless charger (qi charging). overall, we are happy with the iphone.\n \nit’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of apple is fabulous. camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n \nperformance very strong charging\n \nlightning fast,titanium tantrums\n \nfast charging\n \nthis is my 1 st pro iphone. and so far i’m really impressed with the performance and simplicity of the product.\n \nbest iphone ever used\n \nbattery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese hai to isse badiya phone nahi hai market ne phil haal\n \ni have purchased natural titanium and it's really awesome. my first phone purchased with my hardwork.\n \nno heating issue till now running well with the new software update i have installed lots of apps and the ph is running well\n \nwe have received the iphone 15 pro max, natural titanium color, and 256 gb storage capacity. the phone is good-looking and fast. it gets charged with the apple 20w usb-c power adapter  (purchased separately). it also charges well using my 3-year-old mi wireless charger (qi charging). overall, we are happy with the iphone.\n \nit’s a fantastic phone…the feel and comfort in hand is awesome…looks stunning…also the brand appeal of apple is fabulous. camera is the best, performance is over the top…really fast and the games you can play are of play station’s…can any other phone do that…also the video quality is very nice…\n \nperf ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
reviews_token = word_tokenize(reviews)

# %%
from nltk.corpus import stopwords
reviews_no_stopwords = [w for w in reviews_token if not w in stopwords.words()]

# %%
reviews_no_stopwords
# Out:
# ['’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  'qi',
#  'charging',
#  ')',
#  '.',
#  ',',
#  'happy',
#  'iphone',
#  '.',
#  '’',
#  'fantastic',
#  'phone…the',
#  'feel',
#  'comfort',
#  'hand',
#  'awesome…looks',
#  'stunning…also',
#  'brand',
#  'appeal',
#  'apple',
#  'fabulous',
#  '.',
#  'camera',
#  ',',
#  'performance',
#  'top…really',
#  'fast',
#  'games',
#  'play',
#  'play',
#  'station',
#  '’',
#  's…can',
#  'phone',
#  'that…also',
#  'video',
#  'quality',
#  'nice…',
#  'performance',
#  'strong',
#  'charging',
#  'lightning',
#  'fast',
#  ',',
#  'titanium',
#  'tantrums',
#  'fast',
#  'charging',
#  '1',
#  'st',
#  'pro',
#  'iphone',
#  '.',
#  '’',
#  'impressed',
#  'performance',
#  'simplicity',
#  'product',
#  '.',
#  'iphone',
#  'battery',
#  '10/10cemra',
#  '10/10performance',
#  '10/10disign',
#  '10/10display',
#  '10/10agar',
#  'pese',
#  'badiya',
#  'phone',
#  'market',
#  'phil',
#  'haal',
#  'purchased',
#  'natural',
#  'titanium',
#  "'s",
#  'awesome',
#  '.',
#  'phone',
#  'purchased',
#  'hardwork',
#  '.',
#  'heating',
#  'issue',
#  'running',
#  'software',
#  'update',
#  'installed',
#  'lots',
#  'apps',
#  'ph',
#  'running',
#  'received',
#  'iphone',
#  '15',
#  'pro',
#  'max',
#  ',',
#  'natural',
#  'titanium',
#  'color',
#  ',',
#  '256',
#  'gb',
#  'storage',
#  'capacity',
#  '.',
#  'phone',
#  'good-looking',
#  'fast',
#  '.',
#  'charged',
#  'apple',
#  '20w',
#  'usb-c',
#  'power',
#  'adapter',
#  '(',
#  'purchased',
#  'separately',
#  ')',
#  '.',
#  'charges',
#  '3-year-old',
#  'wireless',
#  'charger',
#  '(',
#  ...]

# %%
reviews = ' '.join(reviews_no_stopwords)
reviews
# Out:
# "’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage ca ...

# %% [markdown]
#  Word Cloud Visualization

# %%
def plot_cloud(wordcloud):
  plt.figure(figure=(60,40))
  plt.imshow(wordcloud)
  plt.axis('off')

# %%
from wordcloud import WordCloud, STOPWORDS
STOPWORDS.add('refresh')
wordcloud = WordCloud(width = 3000,
                      height = 2000,
                      background_color='black',
                      max_words=70,
                      colormap='Set1',
                      stopwords=STOPWORDS).generate(reviews)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
reviews1 = reviews
reviews1[0:1000]
# Out:
# "’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can"

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
one_block = reviews1[0:1000]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10/10performance 10/10disign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  10/10display
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10/10agar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  badiya phone market
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phil haal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pro max , natural titanium color ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     256
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  gb storage capacity . phone good-looking fast . charged apple
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20w
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  usb-c power adapter ( purchased separately ) . charges
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can</div></span>

# %%
one_block
# Out:
# "’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can phone that…also video quality nice… performance strong charging lightning fast , titanium tantrums fast charging 1 st pro iphone . ’ impressed performance simplicity product . iphone battery 10/10cemra 10/10performance 10/10disign 10/10display 10/10agar pese badiya phone market phil haal purchased natural titanium 's awesome . phone purchased hardwork . heating issue running software update installed lots apps ph running received iphone 15 pro max , natural titanium color , 256 gb storage capacity . phone good-looking fast . charged apple 20w usb-c power adapter ( purchased separately ) . charges 3-year-old wireless charger ( qi charging ) . , happy iphone . ’ fantastic phone…the feel comfort hand awesome…looks stunning…also brand appeal apple fabulous . camera , performance top…really fast games play play station ’ s…can"

# %%
nw = pd.read_csv('negative-words.txt', error_bad_lines=False, encoding='latin-1')
nw
# Out:
# Skipping line 10: expected 1 fields, saw 2
# Skipping line 14: expected 1 fields, saw 5
# Skipping line 15: expected 1 fields, saw 3
# Skipping line 16: expected 1 fields, saw 2
# Skipping line 18: expected 1 fields, saw 3
# Skipping line 19: expected 1 fields, saw 3
# Skipping line 27: expected 1 fields, saw 3
# Skipping line 28: expected 1 fields, saw 2
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0                                                    ;
# 1                           ; Opinion Lexicon: Negative
# 2                                                     ;
# 3     ; This file contains a list of NEGATIVE opinio...
# 4                                                     ;
# ...                                                 ...
# 4803                                               zaps
# 4804                                             zealot
# 4805                                            zealous
# 4806                                          zealously
# 4807                                             zombie
#
# [4808 rows x 1 columns]

# %%
pw = pd.read_csv('positive-words.txt', error_bad_lines=False, encoding='latin-1')
pw
# Out:
# Skipping line 10: expected 1 fields, saw 2
# Skipping line 14: expected 1 fields, saw 5
# Skipping line 15: expected 1 fields, saw 3
# Skipping line 16: expected 1 fields, saw 2
# Skipping line 18: expected 1 fields, saw 3
# Skipping line 19: expected 1 fields, saw 3
# Skipping line 27: expected 1 fields, saw 3
# Skipping line 28: expected 1 fields, saw 2
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0                                                    ;
# 1                           ; Opinion Lexicon: Positive
# 2                                                     ;
# 3     ; This file contains a list of POSITIVE opinio...
# 4                                                     ;
# ...                                                 ...
# 2026                                           youthful
# 2027                                               zeal
# 2028                                             zenith
# 2029                                               zest
# 2030                                              zippy
#
# [2031 rows x 1 columns]

# %%
pw =pw.iloc[25:]
pw =pw.rename(columns={';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;':'Words'})
pw.reset_index(inplace=True)
pw =pw.drop('index',axis=1)
pw['Score'] = 1
pw
# Out:
#           Words  Score
# 0            a+      1
# 1        abound      1
# 2       abounds      1
# 3     abundance      1
# 4      abundant      1
# ...         ...    ...
# 2001   youthful      1
# 2002       zeal      1
# 2003     zenith      1
# 2004       zest      1
# 2005      zippy      1
#
# [2006 rows x 2 columns]

# %%
nw = nw.iloc[25:]
nw = nw.rename(columns={';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;':'Words'})
nw.reset_index(inplace=True)
nw = nw.drop('index',axis=1)
nw['Score'] = -1
nw
# Out:
#            Words  Score
# 0        2-faced     -1
# 1        2-faces     -1
# 2       abnormal     -1
# 3        abolish     -1
# 4     abominable     -1
# ...          ...    ...
# 4778        zaps     -1
# 4779      zealot     -1
# 4780     zealous     -1
# 4781   zealously     -1
# 4782      zombie     -1
#
# [4783 rows x 2 columns]

# %%
positive = len(pw)

# %%
negative = len(nw)

# %%
totals = len(reviews)

# %%
print('positive reviews:',positive/totals)
# Out:
# positive reviews: 0.26728847435043307

# %%
print('negative reviews:', negative/totals)
# Out:
# negative reviews: 0.6373084610259827

# %% [markdown]
# Vander Lexicon

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores(reviews)
# Out:
# {'neg': 0.049, 'neu': 0.671, 'pos': 0.28, 'compound': 0.9998}

# %%
def get_vader_sentiment(review):
  sia = SentimentIntensityAnalyzer()

  analysis = sia.polarity_scores(review)

  if analysis['compound']>0:
    return 'positive sentiment'
  elif analysis['compound']<0:
    return 'negative sentiment'
  else:
    return 'neutral'

# %%
get_vader_sentiment(reviews)
# Out:
# 'positive sentiment'
